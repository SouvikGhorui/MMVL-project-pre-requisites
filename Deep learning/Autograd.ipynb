# %%
def dy_dx(x):
    return 2*x

# %%
import math
def dy_dx(x):
    return math.cosl(x)

# %% [markdown]
# ## Autograd
#
# Autograd is a core componenet of PyTorch that provides automatic differentiation for tensor opetations. it eables gradient computation, which is essential for training machine learning models using optimization algorighms like gradient descent

# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
y = x**2
y.retain_grad()
z = torch.sin(y)

# %%
z.backward()

# %%
y.grad
# Out:
# tensor(-0.9111)

# %%
x.grad
# Out:
# tensor(0.5332)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
import torch

x = torch.tensor([7.0])
y = torch.tensor(0.0)

w = torch.tensor(1.0)
b = torch.tensor(0.0)

# %%
def binary_cross_entropy(prediction, target):
    epsilon = 1e-8
    prediction = torch.clamp(prediction, epsilon, 1-epsilon)
    return -((target * torch.log(prediction)) + (1 - target) * torch.log(1 - prediction))

# %%
z = w * x + b
y_pred = torch.sigmoid(z)
loss = binary_cross_entropy(y_pred, y)

# %%
print(loss)
# Out:
# tensor([7.0010])

# %%
dloss_dy_pred = (y_pred - y)/ (y_pred * (1 - y_pred))
dy_pred_dz = y_pred * (1 - y_pred)
dz_dw = x
dz_db = 1

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw):{dL_dw}")
print(f'Manual Gradient of loss w.r.t bias (db):{dL_db}')
# Out:
# Manual Gradient of loss w.r.t weight (dw):tensor([6.9936])
# Manual Gradient of loss w.r.t bias (db):tensor([0.9991])

# %%
from torch.jit import TracedModule
x = torch.tensor(7.0)
y = torch.tensor(0.0)

w = torch.tensor(1.0, requires_grad= True)
b = torch.tensor(0.0, requires_grad=True)

# %%
z = w* x + b
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9991, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy(y_pred, y)
loss
# Out:
# tensor(7.0010, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.9936)
# tensor(0.9991)

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
x.grad.zero_()
# Out:
# tensor([0., 0., 0.])

# %%
x.requires_grad_(False)
# Out:
# tensor([1., 2., 3.])

# %%
x
# Out:
# tensor([1., 2., 3.])

# %%
y = x**2

# %%
y
# Out:
# tensor([1., 4., 9.])

# %%
x = torch.tensor(2.0, requires_grad=True)

# %%
z = x.detach()
z
# Out:
# tensor(2.)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1 = z**2

# %%
y1
# Out:
# tensor(4.)

# %%
with torch.no_grad():
    y = x**2
